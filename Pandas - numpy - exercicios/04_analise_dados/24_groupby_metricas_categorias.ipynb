# %% [markdown]
# ## Case 24 - groupby com múltiplas métricas e categorias
#
# Você recebeu os dados:
#
# - cliente: Ana, Bruno, Carlos, Daniela, Eva, Felipe, Gabriel
# - cidade: SP, RJ, SP, RJ, SP, RJ, SP
# - valor_pedido: 120, 250, 80, 300, 150, 500, 220
#
# Faça um código com pandas + NumPy que:
#
# - crie um DataFrame
# - crie uma coluna chamada categoria
#   - "Alto" para valor_pedido >= 200
#   - "Baixo" para os demais
# - mostre um resumo por cidade com:
#   - quantidade de clientes
#   - soma dos pedidos
#   - média dos pedidos
# - dentro de cada cidade, mostre quantos clientes são "Alto" e quantos são "Baixo"

# %%
# Importando o pandas, Numpy e criando um data frame
import pandas as pd
import numpy as np

clientes = pd.DataFrame({
    'cliente': ['Ana', 'Bruno', 'Carlos', 'Daniela', 'Eva', 'Felipe', 'Gabriel'],
    'cidade': ['SP', 'RJ', 'SP', 'RJ', 'SP', 'RJ', 'SP'],
    'valor_pedido': [120, 250, 80, 300, 150, 500, 220 ]
})

clientes
# Out:
#    cliente cidade  valor_pedido
# 0      Ana     SP           120
# 1    Bruno     RJ           250
# 2   Carlos     SP            80
# 3  Daniela     RJ           300
# 4      Eva     SP           150
# 5   Felipe     RJ           500
# 6  Gabriel     SP           220

# %%
# Cria a coluna 'categoria', classificando os pedidos em Alto ou Baixo conforme o valor do pedido.
clientes['categoria'] = np.where(clientes['valor_pedido'] >= 200, 'Alto', 'Baixo')

# Agrupa os dados por cidade e gera um resumo com quantidade de clientes,
# soma total dos pedidos e média do valor dos pedidos.
clientes.groupby('cidade')['valor_pedido'].agg(['count', 'sum', 'mean']).reset_index()
# Out:
#   cidade  count   sum   mean
# 0     RJ      3  1050  350.0
# 1     SP      4   570  142.5

# %%
# Agrupa por cidade e categoria para contar quantos clientes existem em cada combinação.
clientes.groupby(['cidade', 'categoria']).size().reset_index()
# Out:
#   cidade categoria  0
# 0     RJ      Alto  3
# 1     SP      Alto  1
# 2     SP     Baixo  3
